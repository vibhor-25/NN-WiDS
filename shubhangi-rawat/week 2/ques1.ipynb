# %%
import pandas as pd
df=pd.read_csv("fruit_production.csv")
print(df)
# Out:
#    Region  Temperature_F  Rainfall_mm  Humidity_percent  Mangoes_ton  \
# 0       A             73           67                43           56
# 1       B             91           88                64           81
# 2       C             87          134                58          119
# 3       D            102           43                37           22
# 4       E             69           96                70          103
# 5       F             74           66                43           57
# 6       G             91           87                65           80
# 7       H             88          134                59          118
# 8       I            101           44                37           21
# 9       J             68           96                71          104
# 10      K             73           66                44           57
# 11      L             92           87                64           82
# 12      M             87          135                57          118
# ...
