# %%
import pandas as pd
df=pd.read_csv("data_assg1.csv")

# %%
df.loc[(df["value"]>=0)&(df["value"]<0.3),"range"]="low"
df.loc[(df["value"]>=0.3)&(df["value"]<0.7),"range"]="medium"
df.loc[(df["value"]>=0.7)&(df["value"]<1),"range"]="high"

# %%
df.to_csv("changedCSV.csv", index=False)
dfChanged=pd.read_csv("changedCSV.csv")
dfChanged=df[df["range"]!="low"]
print(dfChanged)
# Out:
#      value   range
# 2   0.3004  medium
# 4   0.9413    high
# 5   0.9468    high
# 6   0.6081  medium
# 8   0.8698    high
# ..     ...     ...
# 93  0.8858    high
# 95  0.8330    high
# 96  0.6708  medium
# 97  0.3285  medium
# 99  0.8291    high
#
# [70 rows x 2 columns]
